# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import re

# %%
df= pd.read_csv(r'/kaggle/input/quantium-forage-data-sets/QVI_transaction_data.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 264836 entries, 0 to 264835
# Data columns (total 8 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   DATE            264836 non-null  object
#  1   STORE_NBR       264836 non-null  int64
#  2   LYLTY_CARD_NBR  264836 non-null  int64
#  3   TXN_ID          264836 non-null  int64
#  4   PROD_NBR        264836 non-null  int64
#  5   PROD_NAME       264836 non-null  object
#  6   PROD_QTY        264836 non-null  int64
#  7   TOT_SALES       264836 non-null  float64
# dtypes: float64(1), int64(5), object(2)
# memory usage: 16.2+ MB

# %%
df['DATE'] = pd.to_datetime(df['DATE'])

# %%
df['PROD_NAME'].unique()
# Out:
# array(['Natural Chip        Compny SeaSalt175g',
#        'CCs Nacho Cheese    175g',
#        'Smiths Crinkle Cut  Chips Chicken 170g',
#        'Smiths Chip Thinly  S/Cream&Onion 175g',
#        'Kettle Tortilla ChpsHny&Jlpno Chili 150g',
#        'Old El Paso Salsa   Dip Tomato Mild 300g',
#        'Smiths Crinkle Chips Salt & Vinegar 330g',
#        'Grain Waves         Sweet Chilli 210g',
#        'Doritos Corn Chip Mexican Jalapeno 150g',
#        'Grain Waves Sour    Cream&Chives 210G',
#        'Kettle Sensations   Siracha Lime 150g',
#        'Twisties Cheese     270g', 'WW Crinkle Cut      Chicken 175g',
#        'Thins Chips Light&  Tangy 175g', 'CCs Original 175g',
#        'Burger Rings 220g', 'NCC Sour Cream &    Garden Chives 175g',
#        'Doritos Corn Chip Southern Chicken 150g',
#        'Cheezels Cheese Box 125g', 'Smiths Crinkle      Original 330g',
#        'Infzns Crn Crnchers Tangy Gcamole 110g',
#        'Kettle Sea Salt     And Vinegar 175g',
#        'Smiths Chip Thinly  Cut Original 175g', 'Kettle Original 175g',
#        'Red Rock Deli Thai  Chilli&Lime 150g',
#        'Pringles Sthrn FriedChicken 134g', 'Pringles Sweet&Spcy BBQ 134g',
#        'Red Rock Deli SR    Salsa & Mzzrlla 150g',
#        'Thins Chips         Originl saltd 175g',
#        'Red Rock Deli Sp    Salt & Truffle 150G',
#        'Smiths Thinly       Swt Chli&S/Cream175G', 'Kettle Chilli 175g',
#        'Doritos Mexicana    170g',
#        'Smiths Crinkle Cut  French OnionDip 150g',
#        'Natural ChipCo      Hony Soy Chckn175g',
#        'Dorito Corn Chp     Supreme 380g', 'Twisties Chicken270g',
#        'Smiths Thinly Cut   Roast Chicken 175g',
#        'Smiths Crinkle Cut  Tomato Salsa 150g',
#        'Kettle Mozzarella   Basil & Pesto 175g',
#        'Infuzions Thai SweetChili PotatoMix 110g',
#        'Kettle Sensations   Camembert & Fig 150g',
#        'Smith Crinkle Cut   Mac N Cheese 150g',
#        'Kettle Honey Soy    Chicken 175g',
#        'Thins Chips Seasonedchicken 175g',
#        'Smiths Crinkle Cut  Salt & Vinegar 170g',
#        'Infuzions BBQ Rib   Prawn Crackers 110g',
#        'GrnWves Plus Btroot & Chilli Jam 180g',
#        'Tyrrells Crisps     Lightly Salted 165g',
#        'Kettle Sweet Chilli And Sour Cream 175g',
#        'Doritos Salsa       Medium 300g', 'Kettle 135g Swt Pot Sea Salt',
#        'Pringles SourCream  Onion 134g',
#        'Doritos Corn Chips  Original 170g',
#        'Twisties Cheese     Burger 250g',
#        'Old El Paso Salsa   Dip Chnky Tom Ht300g',
#        'Cobs Popd Swt/Chlli &Sr/Cream Chips 110g',
#        'Woolworths Mild     Salsa 300g',
#        'Natural Chip Co     Tmato Hrb&Spce 175g',
#        'Smiths Crinkle Cut  Chips Original 170g',
#        'Cobs Popd Sea Salt  Chips 110g',
#        'Smiths Crinkle Cut  Chips Chs&Onion170g',
#        'French Fries Potato Chips 175g',
#        'Old El Paso Salsa   Dip Tomato Med 300g',
#        'Doritos Corn Chips  Cheese Supreme 170g',
#        'Pringles Original   Crisps 134g',
#        'RRD Chilli&         Coconut 150g',
#        'WW Original Corn    Chips 200g',
#        'Thins Potato Chips  Hot & Spicy 175g',
#        'Cobs Popd Sour Crm  &Chives Chips 110g',
#        'Smiths Crnkle Chip  Orgnl Big Bag 380g',
#        'Doritos Corn Chips  Nacho Cheese 170g',
#        'Kettle Sensations   BBQ&Maple 150g',
#        'WW D/Style Chip     Sea Salt 200g',
#        'Pringles Chicken    Salt Crips 134g',
#        'WW Original Stacked Chips 160g',
#        'Smiths Chip Thinly  CutSalt/Vinegr175g', 'Cheezels Cheese 330g',
#        'Tostitos Lightly    Salted 175g',
#        'Thins Chips Salt &  Vinegar 175g',
#        'Smiths Crinkle Cut  Chips Barbecue 170g', 'Cheetos Puffs 165g',
#        'RRD Sweet Chilli &  Sour Cream 165g',
#        'WW Crinkle Cut      Original 175g',
#        'Tostitos Splash Of  Lime 175g', 'Woolworths Medium   Salsa 300g',
#        'Kettle Tortilla ChpsBtroot&Ricotta 150g',
#        'CCs Tasty Cheese    175g', 'Woolworths Cheese   Rings 190g',
#        'Tostitos Smoked     Chipotle 175g', 'Pringles Barbeque   134g',
#        'WW Supreme Cheese   Corn Chips 200g',
#        'Pringles Mystery    Flavour 134g',
#        'Tyrrells Crisps     Ched & Chives 165g',
#        'Snbts Whlgrn Crisps Cheddr&Mstrd 90g',
#        'Cheetos Chs & Bacon Balls 190g', 'Pringles Slt Vingar 134g',
#        'Infuzions SourCream&Herbs Veg Strws 110g',
#        'Kettle Tortilla ChpsFeta&Garlic 150g',
#        'Infuzions Mango     Chutny Papadums 70g',
#        'RRD Steak &         Chimuchurri 150g',
#        'RRD Honey Soy       Chicken 165g',
#        'Sunbites Whlegrn    Crisps Frch/Onin 90g',
#        'RRD Salt & Vinegar  165g', 'Doritos Cheese      Supreme 330g',
#        'Smiths Crinkle Cut  Snag&Sauce 150g',
#        'WW Sour Cream &OnionStacked Chips 160g',
#        'RRD Lime & Pepper   165g',
#        'Natural ChipCo Sea  Salt & Vinegr 175g',
#        'Red Rock Deli Chikn&Garlic Aioli 150g',
#        'RRD SR Slow Rst     Pork Belly 150g', 'RRD Pc Sea Salt     165g',
#        'Smith Crinkle Cut   Bolognese 150g', 'Doritos Salsa Mild  300g'],
#       dtype=object)

# %%
df['PDWT_grams'] = df['PROD_NAME'].replace('[a-zA-Z/&]', '', regex= True).astype('int')

# %%
df['PROD_NAME'] = df['PROD_NAME'].replace('[0-9]{2,3}[gG]$', '', regex= True).astype('str')

# %%
df['PROD_NAME'] = df['PROD_NAME'].replace('&', ' & ', regex= True).astype('str')

# %%
df['PROD_NAME'] = df['PROD_NAME'].replace(r'\s{2,4}',' ', regex= True).astype('str')

# %%
df['PROD_NAME'] = df['PROD_NAME'].replace(r'[/\*()_-]','', regex= True).astype('str')

# %%
df['PROD_NAME'] = df['PROD_NAME'].str.strip()

# %%
df['PROD_NAME'].unique()
# Out:
# array(['Natural Chip  Compny SeaSalt', 'CCs Nacho Cheese',
#        'Smiths Crinkle Cut Chips Chicken',
#        'Smiths Chip Thinly SCream & Onion',
#        'Kettle Tortilla ChpsHny & Jlpno Chili',
#        'Old El Paso Salsa Dip Tomato Mild',
#        'Smiths Crinkle Chips Salt & Vinegar',
#        'Grain Waves   Sweet Chilli', 'Doritos Corn Chip Mexican Jalapeno',
#        'Grain Waves Sour Cream & Chives',
#        'Kettle Sensations Siracha Lime', 'Twisties Cheese',
#        'WW Crinkle Cut  Chicken', 'Thins Chips Light & Tangy',
#        'CCs Original', 'Burger Rings', 'NCC Sour Cream &  Garden Chives',
#        'Doritos Corn Chip Southern Chicken', 'Cheezels Cheese Box',
#        'Smiths Crinkle  Original', 'Infzns Crn Crnchers Tangy Gcamole',
#        'Kettle Sea Salt  And Vinegar', 'Smiths Chip Thinly Cut Original',
#        'Kettle Original', 'Red Rock Deli Thai Chilli & Lime',
#        'Pringles Sthrn FriedChicken', 'Pringles Sweet & Spcy BBQ',
#        'Red Rock Deli SR Salsa & Mzzrlla', 'Thins Chips   Originl saltd',
#        'Red Rock Deli Sp Salt & Truffle',
#        'Smiths Thinly  Swt Chli & SCream', 'Kettle Chilli',
#        'Doritos Mexicana', 'Smiths Crinkle Cut French OnionDip',
#        'Natural ChipCo  Hony Soy Chckn', 'Dorito Corn Chp  Supreme',
#        'Twisties Chicken', 'Smiths Thinly Cut Roast Chicken',
#        'Smiths Crinkle Cut Tomato Salsa',
#        'Kettle Mozzarella Basil & Pesto',
#        'Infuzions Thai SweetChili PotatoMix',
#        'Kettle Sensations Camembert & Fig',
#        'Smith Crinkle Cut Mac N Cheese', 'Kettle Honey Soy Chicken',
#        'Thins Chips Seasonedchicken', 'Smiths Crinkle Cut Salt & Vinegar',
#        'Infuzions BBQ Rib Prawn Crackers',
#        'GrnWves Plus Btroot & Chilli Jam',
#        'Tyrrells Crisps  Lightly Salted',
#        'Kettle Sweet Chilli And Sour Cream', 'Doritos Salsa  Medium',
#        'Kettle 135g Swt Pot Sea Salt', 'Pringles SourCream Onion',
#        'Doritos Corn Chips Original', 'Twisties Cheese  Burger',
#        'Old El Paso Salsa Dip Chnky Tom Ht',
#        'Cobs Popd SwtChlli & SrCream Chips', 'Woolworths Mild  Salsa',
#        'Natural Chip Co  Tmato Hrb & Spce',
#        'Smiths Crinkle Cut Chips Original', 'Cobs Popd Sea Salt Chips',
#        'Smiths Crinkle Cut Chips Chs & Onion',
#        'French Fries Potato Chips', 'Old El Paso Salsa Dip Tomato Med',
#        'Doritos Corn Chips Cheese Supreme', 'Pringles Original Crisps',
#        'RRD Chilli &   Coconut', 'WW Original Corn Chips',
#        'Thins Potato Chips Hot & Spicy',
#        'Cobs Popd Sour Crm & Chives Chips',
#        'Smiths Crnkle Chip Orgnl Big Bag',
#        'Doritos Corn Chips Nacho Cheese', 'Kettle Sensations BBQ & Maple',
#        'WW DStyle Chip  Sea Salt', 'Pringles Chicken Salt Crips',
#        'WW Original Stacked Chips', 'Smiths Chip Thinly CutSaltVinegr',
#        'Cheezels Cheese', 'Tostitos Lightly Salted',
#        'Thins Chips Salt & Vinegar', 'Smiths Crinkle Cut Chips Barbecue',
#        'Cheetos Puffs', 'RRD Sweet Chilli & Sour Cream',
#        'WW Crinkle Cut  Original', 'Tostitos Splash Of Lime',
#        'Woolworths Medium Salsa', 'Kettle Tortilla ChpsBtroot & Ricotta',
#        'CCs Tasty Cheese', 'Woolworths Cheese Rings',
#        'Tostitos Smoked  Chipotle', 'Pringles Barbeque',
#        'WW Supreme Cheese Corn Chips', 'Pringles Mystery Flavour',
#        'Tyrrells Crisps  Ched & Chives',
#        'Snbts Whlgrn Crisps Cheddr & Mstrd', 'Cheetos Chs & Bacon Balls',
#        'Pringles Slt Vingar', 'Infuzions SourCream & Herbs Veg Strws',
#        'Kettle Tortilla ChpsFeta & Garlic',
#        'Infuzions Mango  Chutny Papadums', 'RRD Steak &   Chimuchurri',
#        'RRD Honey Soy  Chicken', 'Sunbites Whlegrn Crisps FrchOnin',
#        'RRD Salt & Vinegar', 'Doritos Cheese  Supreme',
#        'Smiths Crinkle Cut Snag & Sauce',
#        'WW Sour Cream & OnionStacked Chips', 'RRD Lime & Pepper',
#        'Natural ChipCo Sea Salt & Vinegr',
#        'Red Rock Deli Chikn & Garlic Aioli',
#        'RRD SR Slow Rst  Pork Belly', 'RRD Pc Sea Salt',
#        'Smith Crinkle Cut Bolognese', 'Doritos Salsa Mild'], dtype=object)

# %%
df.drop_duplicates(inplace=True)

# %%
df_sort = df['PROD_NAME'].value_counts().reset_index()

# %%
df = df.merge(df_sort,on ='PROD_NAME').sort_values(by='count')

# %%
df = df.sort_values(by='count', ascending=False)

# %%
df.head()
# Out:
#              DATE  STORE_NBR  LYLTY_CARD_NBR  TXN_ID  PROD_NBR  \
# 207730 2019-01-13         79           79250   77824       102
# 257265 2018-09-22        253          253173  253808       102
# 72059  2018-12-07         59           59334   55965       102
# 253416 2019-06-26        203          203219  203219       102
# 241440 2018-08-03         37           37270   33845       102
#
#                               PROD_NAME  PROD_QTY  TOT_SALES  PDWT_grams  \
# 207730  Kettle Mozzarella Basil & Pesto         2       10.8         175
# 257265  Kettle Mozzarella Basil & Pesto         2       10.8         175
# 72059   Kettle Mozzarella Basil & Pesto         2       10.8         175
# 253416  Kettle Mozzarella Basil & Pesto         2       10.8         175
# 241440  Kettle Mozzarella Basil & Pesto         2       10.8         175
#
#         count
# 207730   3304
# 257265   3304
# 72059    3304
# 253416   3304
# 241440   3304

# %%
df.drop(columns='count', inplace=True)

# %%
df[df['PROD_NAME'].str.contains('Salsa', regex=False)]
# Out:
#              DATE  STORE_NBR  LYLTY_CARD_NBR  TXN_ID  PROD_NBR  \
# 45592  2019-01-13        152          152210  151635        65
# 160808 2018-09-01        125          125329  129602        65
# 195163 2019-04-18        138          138127  141274        65
# 194924 2018-07-27        134          134276  138110        65
# 221873 2019-02-17        110          110119  112377        65
# ...           ...        ...             ...     ...       ...
# 213034 2018-09-21        183          183017  184857        76
# 206919 2019-05-25         62           62256   59305        76
# 223529 2019-02-06        152          152058  150597        76
# 57605  2019-04-30         43           43208   40046        76
# 115420 2019-02-25        236          236158  239508        76
#
#                                  PROD_NAME  PROD_QTY  TOT_SALES  PDWT_grams
# 45592   Old El Paso Salsa Dip Chnky Tom Ht         2       10.2         300
# 160808  Old El Paso Salsa Dip Chnky Tom Ht         2       10.2         300
# 195163  Old El Paso Salsa Dip Chnky Tom Ht         2       10.2         300
# 194924  Old El Paso Salsa Dip Chnky Tom Ht         2       10.2         300
# 221873  Old El Paso Salsa Dip Chnky Tom Ht         2       10.2         300
# ...                                    ...       ...        ...         ...
# 213034             Woolworths Medium Salsa         2        3.0         300
# 206919             Woolworths Medium Salsa         2        3.0         300
# 223529             Woolworths Medium Salsa         2        3.0         300
# 57605              Woolworths Medium Salsa         2        3.0         300
# 115420             Woolworths Medium Salsa         2        3.0         300
#
# [18094 rows x 9 columns]

# %%
df.isna().value_counts()
# Out:
# DATE   STORE_NBR  LYLTY_CARD_NBR  TXN_ID  PROD_NBR  PROD_NAME  PROD_QTY  TOT_SALES  PDWT_grams
# False  False      False           False   False     False      False     False      False         264835
# Name: count, dtype: int64

# %%
df[['PROD_QTY', 'TOT_SALES']].agg(['mean','max','min'])
# Out:
#         PROD_QTY   TOT_SALES
# mean    1.907308    7.304205
# max   200.000000  650.000000
# min     1.000000    1.500000

# %%
df[df['PROD_QTY']==200]
# Out:
#             DATE  STORE_NBR  LYLTY_CARD_NBR  TXN_ID  PROD_NBR  \
# 69762 2018-08-19        226          226000  226201         4
# 69763 2019-05-20        226          226000  226210         4
#
#                       PROD_NAME  PROD_QTY  TOT_SALES  PDWT_grams
# 69762  Dorito Corn Chp  Supreme       200      650.0         380
# 69763  Dorito Corn Chp  Supreme       200      650.0         380

# %%
df[df['LYLTY_CARD_NBR']==226000]
# Out:
#             DATE  STORE_NBR  LYLTY_CARD_NBR  TXN_ID  PROD_NBR  \
# 69762 2018-08-19        226          226000  226201         4
# 69763 2019-05-20        226          226000  226210         4
#
#                       PROD_NAME  PROD_QTY  TOT_SALES  PDWT_grams
# 69762  Dorito Corn Chp  Supreme       200      650.0         380
# 69763  Dorito Corn Chp  Supreme       200      650.0         380

# %%
df.drop(index=[69763,69762], inplace=True)

# %%
df['DATE'].value_counts()
# Out:
# DATE
# 2018-12-24    939
# 2018-12-23    917
# 2018-12-22    915
# 2018-12-19    906
# 2018-12-18    862
#              ...
# 2018-12-12    664
# 2019-06-24    662
# 2019-06-13    659
# 2018-10-18    658
# 2018-11-25    648
# Name: count, Length: 364, dtype: int64

# %%
dates = pd.date_range(start='2018-07-01', end='2019-06-30')

# %%
dates = pd.DataFrame(dates)

# %%
dates.columns = ['DATE']

# %%
df = df.merge(dates, on='DATE', how='outer')

# %%
plt.figure(figsize=(14,6))
sns.lineplot(data=df.value_counts(subset=df['DATE']).reset_index(), x='DATE', y='count').set_title('Customer Counts Over Time')
# Out:
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# Text(0.5, 1.0, 'Customer Counts Over Time')

# %%
salecount = df.value_counts(subset=df['DATE']).reset_index()

# %%
sales_dec = salecount.query('"2018-12-01" <= DATE < "2019-01-01"').sort_values(by='DATE')
sales_dec
# Out:
#           DATE  count
# 146 2018-12-01    732
# 291 2018-12-02    703
# 107 2018-12-03    740
# 269 2018-12-04    707
# 243 2018-12-05    711
# 298 2018-12-06    701
# 285 2018-12-07    705
# 355 2018-12-08    672
# 314 2018-12-09    697
# 225 2018-12-10    715
# 70  2018-12-11    750
# 359 2018-12-12    664
# 203 2018-12-13    720
# 91  2018-12-14    744
# 174 2018-12-15    725
# 38  2018-12-16    761
# 10  2018-12-17    786
# 4   2018-12-18    862
# 3   2018-12-19    906
# 5   2018-12-20    855
# 6   2018-12-21    842
# 2   2018-12-22    915
# 1   2018-12-23    917
# 0   2018-12-24    939
# 364 2018-12-25      1
# 60  2018-12-26    753
# 140 2018-12-27    732
# 204 2018-12-28    720
# 280 2018-12-29    706
# 81  2018-12-30    747
# 266 2018-12-31    708

# %%
plt.figure(figsize=(14,6))
sns.lineplot(data=sales_dec, x='DATE', y='count').set_title('Customer Counts Over Time')
# Out:
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# Text(0.5, 1.0, 'Customer Counts Over Time')

# %%
df[['DATE','TOT_SALES']].groupby('DATE').sum()
# Out:
#             TOT_SALES
# DATE
# 2018-07-01     5372.2
# 2018-07-02     5315.4
# 2018-07-03     5321.8
# 2018-07-04     5309.9
# 2018-07-05     5080.9
# ...               ...
# 2019-06-26     5305.0
# 2019-06-27     5202.8
# 2019-06-28     5299.6
# 2019-06-29     5497.6
# 2019-06-30     5423.4
#
# [365 rows x 1 columns]

# %%
plt.figure(figsize=(14,6))
sns.lineplot(data=df[['DATE','TOT_SALES']].groupby('DATE').sum(), x='DATE', y='TOT_SALES').set_title('Total_Sales Over Time')
# Out:
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# Text(0.5, 1.0, 'Total_Sales Over Time')

# %%
tot_sales = df[['DATE','TOT_SALES']].groupby('DATE').sum()

# %%
sales_dec = tot_sales.query('"2018-12-01" <= DATE < "2019-01-01"').sort_values(by='DATE')

# %%
plt.figure(figsize=(14,6))
sns.lineplot(data=sales_dec, x='DATE', y='TOT_SALES').set_title('Total_Sales Over December Month')
# Out:
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# Text(0.5, 1.0, 'Total_Sales Over December Month')

# %%
df.head()
# Out:
#         DATE  STORE_NBR  LYLTY_CARD_NBR    TXN_ID  PROD_NBR  \
# 0 2018-07-01       51.0         51073.0   46774.0     102.0
# 1 2018-07-01      216.0        216358.0  216188.0     102.0
# 2 2018-07-01      203.0        203248.0  203329.0     102.0
# 3 2018-07-01       75.0         75310.0   74681.0     102.0
# 4 2018-07-01       23.0         23124.0   19481.0     102.0
#
#                          PROD_NAME  PROD_QTY  TOT_SALES  PDWT_grams
# 0  Kettle Mozzarella Basil & Pesto       1.0        5.4       175.0
# 1  Kettle Mozzarella Basil & Pesto       2.0       10.8       175.0
# 2  Kettle Mozzarella Basil & Pesto       2.0       10.8       175.0
# 3  Kettle Mozzarella Basil & Pesto       2.0       10.8       175.0
# 4  Kettle Mozzarella Basil & Pesto       2.0       10.8       175.0

# %%
df.rename(columns={'PDWT_grams':'PACK_SIZE'}, inplace=True)

# %%
df['PACK_SIZE'].unique()
# Out:
# array([175., 150., 110., 165., 135., 380., 170., 134., 330., 270., 250.,
#        210., 300.,  90., 220., 190., 200.,  70., 160., 180., 125.,  nan])

# %%
df['PACK_SIZE'].agg(['mean', 'max', 'min'])
# Out:
# mean    182.42554
# max     380.00000
# min      70.00000
# Name: PACK_SIZE, dtype: float64

# %%
df.PACK_SIZE.value_counts()
# Out:
# PACK_SIZE
# 175.0    66389
# 150.0    43131
# 134.0    25102
# 110.0    22387
# 170.0    19983
# 165.0    15297
# 300.0    15166
# 330.0    12540
# 380.0     6416
# 270.0     6285
# 210.0     6272
# 200.0     4473
# 135.0     3257
# 250.0     3169
# 90.0      3008
# 190.0     2995
# 160.0     2970
# 220.0     1564
# 70.0      1507
# 180.0     1468
# 125.0     1454
# Name: count, dtype: int64

# %%
plt.figure(figsize=(14,6))
sns.histplot(df['PACK_SIZE'], bins=20).set_title('Chips_Counts For Each Weight Category')
# Out:
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# Text(0.5, 1.0, 'Chips_Counts For Each Weight Category')

# %%
#BRAND column

df['BRAND']= df['PROD_NAME'].str.split().str[0]

# %%
df.head()
# Out:
#         DATE  STORE_NBR  LYLTY_CARD_NBR    TXN_ID  PROD_NBR  \
# 0 2018-07-01       51.0         51073.0   46774.0     102.0
# 1 2018-07-01      216.0        216358.0  216188.0     102.0
# 2 2018-07-01      203.0        203248.0  203329.0     102.0
# 3 2018-07-01       75.0         75310.0   74681.0     102.0
# 4 2018-07-01       23.0         23124.0   19481.0     102.0
#
#                          PROD_NAME  PROD_QTY  TOT_SALES  PACK_SIZE   BRAND
# 0  Kettle Mozzarella Basil & Pesto       1.0        5.4      175.0  Kettle
# 1  Kettle Mozzarella Basil & Pesto       2.0       10.8      175.0  Kettle
# 2  Kettle Mozzarella Basil & Pesto       2.0       10.8      175.0  Kettle
# 3  Kettle Mozzarella Basil & Pesto       2.0       10.8      175.0  Kettle
# 4  Kettle Mozzarella Basil & Pesto       2.0       10.8      175.0  Kettle

# %%
df['BRAND'].unique()
# Out:
# array(['Kettle', 'Cobs', 'Tyrrells', 'Tostitos', 'Infuzions', 'Smiths',
#        'Thins', 'Doritos', 'Pringles', 'Dorito', 'Twisties', 'Grain',
#        'Cheezels', 'Infzns', 'Old', 'Snbts', 'Natural', 'Burger', 'CCs',
#        'RRD', 'Woolworths', 'Smith', 'WW', 'Red', 'Cheetos', 'GrnWves',
#        'Sunbites', 'NCC', 'French', nan], dtype=object)

# %%
df['BRAND']=df['BRAND'].str.replace('Red', 'RRD', regex=False)

# %%
df['BRAND']=df['BRAND'].str.replace('Infzns', 'Infuzions', regex=False)

# %%
df['BRAND']=df['BRAND'].str.replace('Snbts', 'Sunbites', regex=False)

# %%
df['BRAND']=df['BRAND'].str.replace('Natural', 'NCC', regex=False)

# %%
df['BRAND']=df['BRAND'].str.replace('WW', 'Woolworths', regex=False)

# %%
df['BRAND']=df['BRAND'].str.replace('Smiths', 'Smith', regex=False)

# %%
df['BRAND'].unique()
# Out:
# array(['Kettle', 'Cobs', 'Tyrrells', 'Tostitos', 'Infuzions', 'Smith',
#        'Thins', 'Doritos', 'Pringles', 'Dorito', 'Twisties', 'Grain',
#        'Cheezels', 'Old', 'Sunbites', 'NCC', 'Burger', 'CCs', 'RRD',
#        'Woolworths', 'Cheetos', 'GrnWves', 'French', nan], dtype=object)

# %%
df.query('BRAND == "CCs"')
# Out:
#              DATE  STORE_NBR  LYLTY_CARD_NBR    TXN_ID  PROD_NBR  \
# 513    2018-07-01      169.0        169087.0  171127.0      91.0
# 514    2018-07-01       33.0         33053.0   29755.0      91.0
# 515    2018-07-01       55.0         55073.0   48884.0      91.0
# 516    2018-07-01       74.0         74285.0   73137.0      91.0
# 517    2018-07-01       24.0         24208.0   21476.0      91.0
# ...           ...        ...             ...       ...       ...
# 264669 2019-06-30       70.0         70078.0   67940.0      66.0
# 264670 2019-06-30      106.0        106154.0  107674.0      66.0
# 264671 2019-06-30      137.0        137078.0  139348.0      66.0
# 264672 2019-06-30      232.0        232129.0  235937.0      66.0
# 264673 2019-06-30      138.0        138229.0  141975.0      66.0
#
#                PROD_NAME  PROD_QTY  TOT_SALES  PACK_SIZE BRAND
# 513     CCs Tasty Cheese       2.0        4.2      175.0   CCs
# 514     CCs Tasty Cheese       2.0        4.2      175.0   CCs
# 515     CCs Tasty Cheese       2.0        4.2      175.0   CCs
# 516     CCs Tasty Cheese       1.0        2.1      175.0   CCs
# 517     CCs Tasty Cheese       2.0        4.2      175.0   CCs
# ...                  ...       ...        ...        ...   ...
# 264669  CCs Nacho Cheese       2.0        4.2      175.0   CCs
# 264670  CCs Nacho Cheese       2.0        4.2      175.0   CCs
# 264671  CCs Nacho Cheese       2.0        4.2      175.0   CCs
# 264672  CCs Nacho Cheese       2.0        4.2      175.0   CCs
# 264673  CCs Nacho Cheese       2.0        4.2      175.0   CCs
#
# [4551 rows x 10 columns]

# %%
df['BRAND']=df['BRAND'].str.replace('Grain', 'Grain Waves', regex=False)

# %%
df['BRAND']=df['BRAND'].str.replace('GrnWves', 'Grain Waves', regex=False)

# %%
df['BRAND']=df['BRAND'].str.replace('Dorito', 'Doritos', regex=False)

# %%
df['BRAND']=df['BRAND'].str.replace('Doritoss', 'Doritos', regex=False)

# %%
df['BRAND'].unique()
# Out:
# array(['Kettle', 'Cobs', 'Tyrrells', 'Tostitos', 'Infuzions', 'Smith',
#        'Thins', 'Doritos', 'Pringles', 'Twisties', 'Grain Waves',
#        'Cheezels', 'Old', 'Sunbites', 'NCC', 'Burger', 'CCs', 'RRD',
#        'Woolworths', 'Cheetos', 'French', nan], dtype=object)

# %%
df.head()
# Out:
#         DATE  STORE_NBR  LYLTY_CARD_NBR    TXN_ID  PROD_NBR  \
# 0 2018-07-01       51.0         51073.0   46774.0     102.0
# 1 2018-07-01      216.0        216358.0  216188.0     102.0
# 2 2018-07-01      203.0        203248.0  203329.0     102.0
# 3 2018-07-01       75.0         75310.0   74681.0     102.0
# 4 2018-07-01       23.0         23124.0   19481.0     102.0
#
#                          PROD_NAME  PROD_QTY  TOT_SALES  PACK_SIZE   BRAND
# 0  Kettle Mozzarella Basil & Pesto       1.0        5.4      175.0  Kettle
# 1  Kettle Mozzarella Basil & Pesto       2.0       10.8      175.0  Kettle
# 2  Kettle Mozzarella Basil & Pesto       2.0       10.8      175.0  Kettle
# 3  Kettle Mozzarella Basil & Pesto       2.0       10.8      175.0  Kettle
# 4  Kettle Mozzarella Basil & Pesto       2.0       10.8      175.0  Kettle

# %%
df.BRAND.value_counts().reset_index()
# Out:
#           BRAND  count
# 0        Kettle  41288
# 1         Smith  31822
# 2       Doritos  28145
# 3      Pringles  25102
# 4           RRD  17779
# 5    Woolworths  14757
# 6     Infuzions  14201
# 7         Thins  14075
# 8          Cobs   9693
# 9      Tostitos   9471
# 10     Twisties   9454
# 11          Old   9324
# 12  Grain Waves   7740
# 13          NCC   7469
# 14     Tyrrells   6442
# 15     Cheezels   4603
# 16          CCs   4551
# 17     Sunbites   3008
# 18      Cheetos   2927
# 19       Burger   1564
# 20       French   1418

# %%
df.shape
# Out:
# (264834, 10)

# %%
df_cd = pd.read_csv(r'/kaggle/input/quantium-forage-data-sets/QVI_purchase_behaviour.csv')

# %%
df_cd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 72637 entries, 0 to 72636
# Data columns (total 3 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   LYLTY_CARD_NBR    72637 non-null  int64
#  1   LIFESTAGE         72637 non-null  object
#  2   PREMIUM_CUSTOMER  72637 non-null  object
# dtypes: int64(1), object(2)
# memory usage: 1.7+ MB

# %%
df_cd['LIFESTAGE'].value_counts(ascending=False).reset_index()
# Out:
#                 LIFESTAGE  count
# 0                RETIREES  14805
# 1   OLDER SINGLES/COUPLES  14609
# 2   YOUNG SINGLES/COUPLES  14441
# 3          OLDER FAMILIES   9780
# 4          YOUNG FAMILIES   9178
# 5  MIDAGE SINGLES/COUPLES   7275
# 6            NEW FAMILIES   2549

# %%
df_cd_ls_c = df_cd['LIFESTAGE'].value_counts(ascending=False).reset_index()

# %%
df_cd['PREMIUM_CUSTOMER'].value_counts(ascending=False).reset_index()
# Out:
#   PREMIUM_CUSTOMER  count
# 0       Mainstream  29245
# 1           Budget  24470
# 2          Premium  18922

# %%
df_cd_pc_c = df_cd['PREMIUM_CUSTOMER'].value_counts(ascending=False).reset_index()

# %%
df_cd[df_cd['LYLTY_CARD_NBR'] == 226000.0]
# Out:
#        LYLTY_CARD_NBR       LIFESTAGE PREMIUM_CUSTOMER
# 59694          226000  OLDER FAMILIES          Premium

# %%
df_cd.drop(index=59694, inplace=True)

# %%
df.merge(df_cd, on='LYLTY_CARD_NBR', how='outer')
# Out:
#              DATE  STORE_NBR  LYLTY_CARD_NBR    TXN_ID  PROD_NBR  \
# 0      2018-10-17        1.0          1000.0       1.0       5.0
# 1      2018-09-16        1.0          1002.0       2.0      58.0
# 2      2019-03-07        1.0          1003.0       3.0      52.0
# 3      2019-03-08        1.0          1003.0       4.0     106.0
# 4      2018-11-02        1.0          1004.0       5.0      96.0
# ...           ...        ...             ...       ...       ...
# 264829 2018-10-01       88.0       2370751.0  240394.0      60.0
# 264830 2018-10-24       88.0       2370961.0  240480.0      70.0
# 264831 2018-10-27       88.0       2370961.0  240481.0      65.0
# 264832 2018-12-14       88.0       2373711.0  241815.0      16.0
# 264833 2018-12-25        NaN             NaN       NaN       NaN
#
#                                   PROD_NAME  PROD_QTY  TOT_SALES  PACK_SIZE  \
# 0              Natural Chip  Compny SeaSalt       2.0        6.0      175.0
# 1        Red Rock Deli Chikn & Garlic Aioli       1.0        2.7      150.0
# 2           Grain Waves Sour Cream & Chives       1.0        3.6      210.0
# 3            Natural ChipCo  Hony Soy Chckn       1.0        3.0      175.0
# 4                 WW Original Stacked Chips       1.0        1.9      160.0
# ...                                     ...       ...        ...        ...
# 264829    Kettle Tortilla ChpsFeta & Garlic       2.0        9.2      150.0
# 264830      Tyrrells Crisps  Lightly Salted       2.0        8.4      165.0
# 264831   Old El Paso Salsa Dip Chnky Tom Ht       2.0       10.2      300.0
# 264832  Smiths Crinkle Chips Salt & Vinegar       2.0       11.4      330.0
# 264833                                  NaN       NaN        NaN        NaN
#
#               BRAND              LIFESTAGE PREMIUM_CUSTOMER
# 0               NCC  YOUNG SINGLES/COUPLES          Premium
# 1               RRD  YOUNG SINGLES/COUPLES       Mainstream
# 2       Grain Waves         YOUNG FAMILIES           Budget
# 3               NCC         YOUNG FAMILIES           Budget
# 4        Woolworths  OLDER SINGLES/COUPLES       Mainstream
# ...             ...                    ...              ...
# 264829       Kettle         YOUNG FAMILIES          Premium
# 264830     Tyrrells         OLDER FAMILIES           Budget
# 264831          Old         OLDER FAMILIES           Budget
# 264832        Smith  YOUNG SINGLES/COUPLES       Mainstream
# 264833          NaN                    NaN              NaN
#
# [264834 rows x 12 columns]

# %%
df_merged = df.merge(df_cd, on='LYLTY_CARD_NBR', how='outer')

# %%
df_merged.isna().value_counts()
# Out:
# DATE   STORE_NBR  LYLTY_CARD_NBR  TXN_ID  PROD_NBR  PROD_NAME  PROD_QTY  TOT_SALES  PACK_SIZE  BRAND  LIFESTAGE  PREMIUM_CUSTOMER
# False  False      False           False   False     False      False     False      False      False  False      False               264833
#        True       True            True    True      True       True      True       True       True   True       True                     1
# Name: count, dtype: int64

# %%
df = df_merged

# %%
df
# Out:
#              DATE  STORE_NBR  LYLTY_CARD_NBR    TXN_ID  PROD_NBR  \
# 0      2018-10-17        1.0          1000.0       1.0       5.0
# 1      2018-09-16        1.0          1002.0       2.0      58.0
# 2      2019-03-07        1.0          1003.0       3.0      52.0
# 3      2019-03-08        1.0          1003.0       4.0     106.0
# 4      2018-11-02        1.0          1004.0       5.0      96.0
# ...           ...        ...             ...       ...       ...
# 264829 2018-10-01       88.0       2370751.0  240394.0      60.0
# 264830 2018-10-24       88.0       2370961.0  240480.0      70.0
# 264831 2018-10-27       88.0       2370961.0  240481.0      65.0
# 264832 2018-12-14       88.0       2373711.0  241815.0      16.0
# 264833 2018-12-25        NaN             NaN       NaN       NaN
#
#                                   PROD_NAME  PROD_QTY  TOT_SALES  PACK_SIZE  \
# 0              Natural Chip  Compny SeaSalt       2.0        6.0      175.0
# 1        Red Rock Deli Chikn & Garlic Aioli       1.0        2.7      150.0
# 2           Grain Waves Sour Cream & Chives       1.0        3.6      210.0
# 3            Natural ChipCo  Hony Soy Chckn       1.0        3.0      175.0
# 4                 WW Original Stacked Chips       1.0        1.9      160.0
# ...                                     ...       ...        ...        ...
# 264829    Kettle Tortilla ChpsFeta & Garlic       2.0        9.2      150.0
# 264830      Tyrrells Crisps  Lightly Salted       2.0        8.4      165.0
# 264831   Old El Paso Salsa Dip Chnky Tom Ht       2.0       10.2      300.0
# 264832  Smiths Crinkle Chips Salt & Vinegar       2.0       11.4      330.0
# 264833                                  NaN       NaN        NaN        NaN
#
#               BRAND              LIFESTAGE PREMIUM_CUSTOMER
# 0               NCC  YOUNG SINGLES/COUPLES          Premium
# 1               RRD  YOUNG SINGLES/COUPLES       Mainstream
# 2       Grain Waves         YOUNG FAMILIES           Budget
# 3               NCC         YOUNG FAMILIES           Budget
# 4        Woolworths  OLDER SINGLES/COUPLES       Mainstream
# ...             ...                    ...              ...
# 264829       Kettle         YOUNG FAMILIES          Premium
# 264830     Tyrrells         OLDER FAMILIES           Budget
# 264831          Old         OLDER FAMILIES           Budget
# 264832        Smith  YOUNG SINGLES/COUPLES       Mainstream
# 264833          NaN                    NaN              NaN
#
# [264834 rows x 12 columns]

# %%
df_tcd = df.groupby('LYLTY_CARD_NBR')['TOT_SALES'].sum().sort_values(ascending=False).reset_index()

# %%
df_tcd
# Out:
#        LYLTY_CARD_NBR  TOT_SALES
# 0            230078.0      138.6
# 1             63197.0      132.8
# 2            259009.0      127.2
# 3            162039.0      126.8
# 4             58361.0      124.8
# ...               ...        ...
# 72631        151175.0        1.5
# 72632         41089.0        1.5
# 72633        169206.0        1.5
# 72634        136282.0        1.5
# 72635        266092.0        1.5
#
# [72636 rows x 2 columns]

# %%
df['STORE_NBR']=df['STORE_NBR'].fillna(0).astype(int)

# %%
df['LYLTY_CARD_NBR']=df['LYLTY_CARD_NBR'].fillna(0).astype(int)

# %%
df['TXN_ID']=df['TXN_ID'].fillna(0).astype(int)

# %%
df['PROD_NBR']=df['PROD_NBR'].fillna(0).astype(int)

# %%
df['PROD_QTY']=df['PROD_QTY'].fillna(0).astype(int)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 264834 entries, 0 to 264833
# Data columns (total 12 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   DATE              264834 non-null  datetime64[ns]
#  1   STORE_NBR         264834 non-null  int64
#  2   LYLTY_CARD_NBR    264834 non-null  int64
#  3   TXN_ID            264834 non-null  int64
#  4   PROD_NBR          264834 non-null  int64
#  5   PROD_NAME         264833 non-null  object
#  6   PROD_QTY          264834 non-null  int64
#  7   TOT_SALES         264833 non-null  float64
#  8   PACK_SIZE         264833 non-null  float64
#  9   BRAND             264833 non-null  object
#  10  LIFESTAGE         264833 non-null  object
#  11  PREMIUM_CUSTOMER  264833 non-null  object
# dtypes: datetime64[ns](1), float64(2), int64(5), object(4)
# memory usage: 24.2+ MB

# %%
df.query('LYLTY_CARD_NBR == 230078')
# Out:
#              DATE  STORE_NBR  LYLTY_CARD_NBR  TXN_ID  PROD_NBR  \
# 227711 2018-07-18        230          230078  232416         7
# 227712 2018-07-31        230          230078  232417        85
# 227713 2018-09-26        230          230078  232418        90
# 227714 2018-09-29        230          230078  232419         1
# 227715 2018-10-25        230          230078  232420         2
# 227716 2018-10-29        230          230078  232421        87
# 227717 2018-11-18        230          230078  232422        79
# 227718 2018-12-23        230          230078  232424        17
# 227719 2019-01-09        230          230078  232425        63
# 227720 2019-02-18        230          230078  232426        88
# 227721 2019-03-21        230          230078  232427        82
# 227722 2019-05-09        230          230078  232428        15
# 227723 2019-05-12        230          230078  232429        22
# 227724 2019-05-17        230          230078  232430        68
# 227725 2019-05-27        230          230078  232431        42
# 227726 2019-06-01        230          230078  232432        17
# 227727 2019-06-20        230          230078  232433        91
#
#                                  PROD_NAME  PROD_QTY  TOT_SALES  PACK_SIZE  \
# 227711            Smiths Crinkle  Original         2       11.4      330.0
# 227712              RRD Honey Soy  Chicken         2        6.0      165.0
# 227713           Tostitos Smoked  Chipotle         2        8.8      175.0
# 227714   Smiths Crinkle Cut Chips Barbecue         2        5.8      170.0
# 227715   Cobs Popd Sour Crm & Chives Chips         2        7.6      110.0
# 227716    Infuzions BBQ Rib Prawn Crackers         2        7.6      110.0
# 227717    Smiths Chip Thinly CutSaltVinegr         2        6.0      175.0
# 227718       Kettle Sensations BBQ & Maple         2        9.2      150.0
# 227719        Kettle 135g Swt Pot Sea Salt         2        8.4      135.0
# 227720            Kettle Honey Soy Chicken         2       10.8      175.0
# 227721      Smith Crinkle Cut Mac N Cheese         2        5.2      150.0
# 227722                     Twisties Cheese         2        9.2      270.0
# 227723         Thins Chips   Originl saltd         2        6.6      175.0
# 227724         Pringles Chicken Salt Crips         4       14.8      134.0
# 227725  Doritos Corn Chip Mexican Jalapeno         2        7.8      150.0
# 227726       Kettle Sensations BBQ & Maple         2        9.2      150.0
# 227727                    CCs Tasty Cheese         2        4.2      175.0
#
#             BRAND       LIFESTAGE PREMIUM_CUSTOMER
# 227711      Smith  OLDER FAMILIES           Budget
# 227712        RRD  OLDER FAMILIES           Budget
# 227713   Tostitos  OLDER FAMILIES           Budget
# 227714      Smith  OLDER FAMILIES           Budget
# 227715       Cobs  OLDER FAMILIES           Budget
# 227716  Infuzions  OLDER FAMILIES           Budget
# 227717      Smith  OLDER FAMILIES           Budget
# 227718     Kettle  OLDER FAMILIES           Budget
# 227719     Kettle  OLDER FAMILIES           Budget
# 227720     Kettle  OLDER FAMILIES           Budget
# 227721      Smith  OLDER FAMILIES           Budget
# 227722   Twisties  OLDER FAMILIES           Budget
# 227723      Thins  OLDER FAMILIES           Budget
# 227724   Pringles  OLDER FAMILIES           Budget
# 227725    Doritos  OLDER FAMILIES           Budget
# 227726     Kettle  OLDER FAMILIES           Budget
# 227727        CCs  OLDER FAMILIES           Budget

# %%
df.query('LYLTY_CARD_NBR == 259009')
# Out:
#              DATE  STORE_NBR  LYLTY_CARD_NBR  TXN_ID  PROD_NBR  \
# 252263 2018-07-04        259          259009  257456         1
# 252264 2018-07-19        259          259009  257457        15
# 252265 2018-08-30        259          259009  257458        51
# 252266 2018-09-24        259          259009  257459        60
# 252267 2018-10-13        259          259009  257460        88
# 252268 2018-10-13        259          259009  257460        41
# 252269 2018-12-26        259          259009  257461        50
# 252270 2018-12-27        259          259009  257462        22
# 252271 2019-02-21        259          259009  257463        90
# 252272 2019-03-13        259          259009  257464        65
# 252273 2019-04-12        259          259009  257465        84
# 252274 2019-04-25        259          259009  257466         4
# 252275 2019-04-25        259          259009  257466        94
# 252276 2019-04-26        259          259009  257467        88
# 252277 2019-05-02        259          259009  257468         9
#
#                                    PROD_NAME  PROD_QTY  TOT_SALES  PACK_SIZE  \
# 252263     Smiths Crinkle Cut Chips Barbecue         2        5.8      170.0
# 252264                       Twisties Cheese         2        9.2      270.0
# 252265                      Doritos Mexicana         2        8.8      170.0
# 252266     Kettle Tortilla ChpsFeta & Garlic         2        9.2      150.0
# 252267              Kettle Honey Soy Chicken         2       10.8      175.0
# 252268                    Doritos Salsa Mild         2        5.2      300.0
# 252269               Tostitos Lightly Salted         2        8.8      175.0
# 252270           Thins Chips   Originl saltd         2        6.6      175.0
# 252271             Tostitos Smoked  Chipotle         2        8.8      175.0
# 252272    Old El Paso Salsa Dip Chnky Tom Ht         2       10.2      300.0
# 252273      GrnWves Plus Btroot & Chilli Jam         2        6.2      180.0
# 252274              Dorito Corn Chp  Supreme         2       13.0      380.0
# 252275                          Burger Rings         2        4.6      220.0
# 252276              Kettle Honey Soy Chicken         2       10.8      175.0
# 252277  Kettle Tortilla ChpsBtroot & Ricotta         2        9.2      150.0
#
#               BRAND              LIFESTAGE PREMIUM_CUSTOMER
# 252263        Smith  OLDER SINGLES/COUPLES       Mainstream
# 252264     Twisties  OLDER SINGLES/COUPLES       Mainstream
# 252265      Doritos  OLDER SINGLES/COUPLES       Mainstream
# 252266       Kettle  OLDER SINGLES/COUPLES       Mainstream
# 252267       Kettle  OLDER SINGLES/COUPLES       Mainstream
# 252268      Doritos  OLDER SINGLES/COUPLES       Mainstream
# 252269     Tostitos  OLDER SINGLES/COUPLES       Mainstream
# 252270        Thins  OLDER SINGLES/COUPLES       Mainstream
# 252271     Tostitos  OLDER SINGLES/COUPLES       Mainstream
# 252272          Old  OLDER SINGLES/COUPLES       Mainstream
# 252273  Grain Waves  OLDER SINGLES/COUPLES       Mainstream
# 252274      Doritos  OLDER SINGLES/COUPLES       Mainstream
# 252275       Burger  OLDER SINGLES/COUPLES       Mainstream
# 252276       Kettle  OLDER SINGLES/COUPLES       Mainstream
# 252277       Kettle  OLDER SINGLES/COUPLES       Mainstream

# %%
tp_cd = df_tcd['LYLTY_CARD_NBR'][:20]

# %%
tp_cd
# Out:
# 0     230078.0
# 1      63197.0
# 2     259009.0
# 3     162039.0
# 4      58361.0
# 5     230154.0
# 6      94185.0
# 7     130090.0
# 8     179228.0
# 9     172032.0
# 10    199157.0
# 11    116181.0
# 12    114163.0
# 13      3153.0
# 14     59333.0
# 15    164034.0
# 16     28020.0
# 17    116113.0
# 18    156054.0
# 19    199146.0
# Name: LYLTY_CARD_NBR, dtype: float64

# %%
pd.set_option('display.max_rows',100)

# %%
df_cd['LIFESTAGE'].value_counts(ascending=False).reset_index()
# Out:
#                 LIFESTAGE  count
# 0                RETIREES  14805
# 1   OLDER SINGLES/COUPLES  14609
# 2   YOUNG SINGLES/COUPLES  14441
# 3          OLDER FAMILIES   9779
# 4          YOUNG FAMILIES   9178
# 5  MIDAGE SINGLES/COUPLES   7275
# 6            NEW FAMILIES   2549

# %%
df.query('LYLTY_CARD_NBR in @tp_cd').groupby('LYLTY_CARD_NBR').value_counts(ascending=False).reset_index()
# Out:
#      LYLTY_CARD_NBR       DATE  STORE_NBR  TXN_ID  PROD_NBR  \
# 0              3153 2018-07-04          3    1723        87
# 1              3153 2018-07-13          3    1724        30
# 2              3153 2018-07-22          3    1725        17
# 3              3153 2018-08-21          3    1726        46
# 4              3153 2018-09-08          3    1727        81
# ..              ...        ...        ...     ...       ...
# 295          259009 2019-04-12        259  257465        84
# 296          259009 2019-04-25        259  257466         4
# 297          259009 2019-04-25        259  257466        94
# 298          259009 2019-04-26        259  257467        88
# 299          259009 2019-05-02        259  257468         9
#
#                                 PROD_NAME  PROD_QTY  TOT_SALES  PACK_SIZE  \
# 0        Infuzions BBQ Rib Prawn Crackers         2        7.6      110.0
# 1       Doritos Corn Chips Cheese Supreme         2        8.8      170.0
# 2           Kettle Sensations BBQ & Maple         2        9.2      150.0
# 3                         Kettle Original         2       10.8      175.0
# 4                Pringles Original Crisps         2        7.4      134.0
# ..                                    ...       ...        ...        ...
# 295      GrnWves Plus Btroot & Chilli Jam         2        6.2      180.0
# 296              Dorito Corn Chp  Supreme         2       13.0      380.0
# 297                          Burger Rings         2        4.6      220.0
# 298              Kettle Honey Soy Chicken         2       10.8      175.0
# 299  Kettle Tortilla ChpsBtroot & Ricotta         2        9.2      150.0
#
#            BRAND               LIFESTAGE PREMIUM_CUSTOMER  count
# 0      Infuzions  MIDAGE SINGLES/COUPLES          Premium      1
# 1        Doritos  MIDAGE SINGLES/COUPLES          Premium      1
# 2         Kettle  MIDAGE SINGLES/COUPLES          Premium      1
# 3         Kettle  MIDAGE SINGLES/COUPLES          Premium      1
# 4       Pringles  MIDAGE SINGLES/COUPLES          Premium      1
# ..           ...                     ...              ...    ...
# 295  Grain Waves   OLDER SINGLES/COUPLES       Mainstream      1
# 296      Doritos   OLDER SINGLES/COUPLES       Mainstream      1
# 297       Burger   OLDER SINGLES/COUPLES       Mainstream      1
# 298       Kettle   OLDER SINGLES/COUPLES       Mainstream      1
# 299       Kettle   OLDER SINGLES/COUPLES       Mainstream      1
#
# [300 rows x 13 columns]

# %%
df_tcd_plt = df.query('LYLTY_CARD_NBR in @tp_cd').groupby('LYLTY_CARD_NBR').value_counts(ascending=False).reset_index()

# %%
df_cd.query('LYLTY_CARD_NBR in @tp_cd')
# Out:
#        LYLTY_CARD_NBR               LIFESTAGE PREMIUM_CUSTOMER
# 810              3153  MIDAGE SINGLES/COUPLES          Premium
# 7846            28020          OLDER FAMILIES          Premium
# 16001           58361          YOUNG FAMILIES           Budget
# 16363           59333          YOUNG FAMILIES          Premium
# 17292           63197          OLDER FAMILIES           Budget
# 25958           94185          YOUNG FAMILIES          Premium
# 31050          114163          OLDER FAMILIES           Budget
# 31586          116113   OLDER SINGLES/COUPLES          Premium
# 31654          116181          YOUNG FAMILIES          Premium
# 35338          130090          YOUNG FAMILIES           Budget
# 41873          156054  MIDAGE SINGLES/COUPLES          Premium
# 42813          162039          OLDER FAMILIES       Mainstream
# 43370          164034                RETIREES           Budget
# 45905          172032   YOUNG SINGLES/COUPLES       Mainstream
# 47959          179228          YOUNG FAMILIES           Budget
# 52864          199146          YOUNG FAMILIES           Budget
# 52875          199157          YOUNG FAMILIES          Premium
# 60925          230078          OLDER FAMILIES           Budget
# 61001          230154          OLDER FAMILIES           Budget
# 69017          259009   OLDER SINGLES/COUPLES       Mainstream

# %%
df.groupby('LYLTY_CARD_NBR')[['TOT_SALES','PROD_QTY']].sum().reset_index()
# Out:
#        LYLTY_CARD_NBR  TOT_SALES  PROD_QTY
# 0                   0        0.0         0
# 1                1000        6.0         2
# 2                1002        2.7         1
# 3                1003        6.6         2
# 4                1004        1.9         1
# ...               ...        ...       ...
# 72632         2370651       13.0         2
# 72633         2370701        7.2         2
# 72634         2370751        9.2         2
# 72635         2370961       18.6         4
# 72636         2373711       11.4         2
#
# [72637 rows x 3 columns]

# %%
df_cd_agg = df.groupby('LYLTY_CARD_NBR')[['TOT_SALES','PROD_QTY']].sum().reset_index()

# %%
df_cd_merged =df_cd.merge(df_cd_agg,on='LYLTY_CARD_NBR', how='inner')

# %%
df_cd_merged.sort_values(by='TOT_SALES', ascending=False)
# Out:
#        LYLTY_CARD_NBR              LIFESTAGE PREMIUM_CUSTOMER  TOT_SALES  \
# 60924          230078         OLDER FAMILIES           Budget      138.6
# 17292           63197         OLDER FAMILIES           Budget      132.8
# 69016          259009  OLDER SINGLES/COUPLES       Mainstream      127.2
# 42813          162039         OLDER FAMILIES       Mainstream      126.8
# 16001           58361         YOUNG FAMILIES           Budget      124.8
# ...               ...                    ...              ...        ...
# 40348          151175         YOUNG FAMILIES           Budget        1.5
# 11310           41089  YOUNG SINGLES/COUPLES          Premium        1.5
# 45088          169206  YOUNG SINGLES/COUPLES          Premium        1.5
# 36833          136282  YOUNG SINGLES/COUPLES       Mainstream        1.5
# 70934          266092               RETIREES       Mainstream        1.5
#
#        PROD_QTY
# 60924        36
# 17292        32
# 69016        30
# 42813        36
# 16001        28
# ...         ...
# 40348         1
# 11310         1
# 45088         1
# 36833         1
# 70934         1
#
# [72636 rows x 5 columns]

# %%
df_cd_merged.groupby('PREMIUM_CUSTOMER')[['TOT_SALES', 'PROD_QTY']].sum().sort_values(by='TOT_SALES', ascending=False)
# Out:
#                   TOT_SALES  PROD_QTY
# PREMIUM_CUSTOMER
# Mainstream        750744.50    193965
# Budget            676211.55    177898
# Premium           506152.95    132859

# %%
df_cd_pc = df_cd_merged.groupby('PREMIUM_CUSTOMER')[['TOT_SALES', 'PROD_QTY']].sum().sort_values(by='TOT_SALES', ascending=False)

# %%
df_cd_pc = df_cd_pc.merge(df_cd_pc_c, on='PREMIUM_CUSTOMER', how='inner')

# %%
df_cd_pc['Chips_Per_Customer'] = df_cd_pc['PROD_QTY']/df_cd_pc['count']

# %%
df_cd_pc
# Out:
#   PREMIUM_CUSTOMER  TOT_SALES  PROD_QTY  count  Chips_Per_Customer
# 0       Mainstream  750744.50    193965  29245            6.632416
# 1           Budget  676211.55    177898  24470            7.270045
# 2          Premium  506152.95    132859  18922            7.021404

# %%
df_cd_pc['Sales_Per_Customer'] = df_cd_pc['TOT_SALES']/df_cd_pc['count']

# %%
df_cd_pc
# Out:
#   PREMIUM_CUSTOMER  TOT_SALES  PROD_QTY  count  Chips_Per_Customer  \
# 0       Mainstream  750744.50    193965  29245            6.632416
# 1           Budget  676211.55    177898  24470            7.270045
# 2          Premium  506152.95    132859  18922            7.021404
#
#    Sales_Per_Customer
# 0           25.670867
# 1           27.634309
# 2           26.749442

# %%
df_cd_merged.groupby('LIFESTAGE')[['TOT_SALES', 'PROD_QTY']].sum().sort_values(by='TOT_SALES', ascending=False)
# Out:
#                         TOT_SALES  PROD_QTY
# LIFESTAGE
# OLDER SINGLES/COUPLES   402420.75    104201
# RETIREES                366470.90     94166
# OLDER FAMILIES          352467.20     94592
# YOUNG FAMILIES          316160.10     84561
# YOUNG SINGLES/COUPLES   260405.30     66634
# MIDAGE SINGLES/COUPLES  184751.30     47721
# NEW FAMILIES             50433.45     12847

# %%
df_cd_ls = df_cd_merged.groupby('LIFESTAGE')[['TOT_SALES', 'PROD_QTY']].sum().sort_values(by='TOT_SALES', ascending=False)

# %%
df_cd_ls = df_cd_ls.merge(df_cd_ls_c, on='LIFESTAGE', how='inner')

# %%
df_cd_ls['Chips_Per_Customer'] = df_cd_ls['PROD_QTY']/df_cd_ls['count']

# %%
df_cd_ls
# Out:
#                 LIFESTAGE  TOT_SALES  PROD_QTY  count  Chips_Per_Customer
# 0   OLDER SINGLES/COUPLES  402420.75    104201  14609            7.132658
# 1                RETIREES  366470.90     94166  14805            6.360419
# 2          OLDER FAMILIES  352467.20     94592   9780            9.671984
# 3          YOUNG FAMILIES  316160.10     84561   9178            9.213445
# 4   YOUNG SINGLES/COUPLES  260405.30     66634  14441            4.614223
# 5  MIDAGE SINGLES/COUPLES  184751.30     47721   7275            6.559588
# 6            NEW FAMILIES   50433.45     12847   2549            5.040016

# %%
df_cd_ls['Sales_Per_Customer'] = df_cd_ls['TOT_SALES']/ df_cd_ls['count']

# %%
df_cd_ls
# Out:
#                 LIFESTAGE  TOT_SALES  PROD_QTY  count  Chips_Per_Customer  \
# 0   OLDER SINGLES/COUPLES  402420.75    104201  14609            7.132658
# 1                RETIREES  366470.90     94166  14805            6.360419
# 2          OLDER FAMILIES  352467.20     94592   9780            9.671984
# 3          YOUNG FAMILIES  316160.10     84561   9178            9.213445
# 4   YOUNG SINGLES/COUPLES  260405.30     66634  14441            4.614223
# 5  MIDAGE SINGLES/COUPLES  184751.30     47721   7275            6.559588
# 6            NEW FAMILIES   50433.45     12847   2549            5.040016
#
#    Sales_Per_Customer
# 0           27.546085
# 1           24.753185
# 2           36.039591
# 3           34.447603
# 4           18.032359
# 5           25.395368
# 6           19.785583

# %%
df_cd.groupby(['LIFESTAGE','PREMIUM_CUSTOMER']).count().rename(columns= {'LYLTY_CARD_NBR':'Cutomer_Counts'})
# Out:
#                                          Cutomer_Counts
# LIFESTAGE              PREMIUM_CUSTOMER
# MIDAGE SINGLES/COUPLES Budget                      1504
#                        Mainstream                  3340
#                        Premium                     2431
# NEW FAMILIES           Budget                      1112
#                        Mainstream                   849
#                        Premium                      588
# OLDER FAMILIES         Budget                      4675
#                        Mainstream                  2831
#                        Premium                     2273
# OLDER SINGLES/COUPLES  Budget                      4929
#                        Mainstream                  4930
#                        Premium                     4750
# RETIREES               Budget                      4454
#                        Mainstream                  6479
#                        Premium                     3872
# YOUNG FAMILIES         Budget                      4017
#                        Mainstream                  2728
#                        Premium                     2433
# YOUNG SINGLES/COUPLES  Budget                      3779
#                        Mainstream                  8088
#                        Premium                     2574

# %%
df_cd_seg_c = df_cd.groupby(['LIFESTAGE','PREMIUM_CUSTOMER']).count().rename(columns= {'LYLTY_CARD_NBR':'Cutomer_Counts'})
df_cd_seg_c = df_cd_seg_c.reset_index()

# %%
plt.figure(figsize=(14,8))
sns.barplot(x='LIFESTAGE', y='Cutomer_Counts', hue='PREMIUM_CUSTOMER',data=df_cd_seg_c)
plt.xlabel(None)
# Out:
# Text(0.5, 0, '')

# %%
df_cd.query('LIFESTAGE == "MIDAGE SINGLES/COUPLES"').count()
# Out:
# LYLTY_CARD_NBR      7275
# LIFESTAGE           7275
# PREMIUM_CUSTOMER    7275
# dtype: int64

# %%
df_cd_merged[['LIFESTAGE','PREMIUM_CUSTOMER','TOT_SALES','PROD_QTY']].groupby(['LIFESTAGE', 'PREMIUM_CUSTOMER']).sum().sort_values(by='TOT_SALES', ascending=False)
# Out:
#                                          TOT_SALES  PROD_QTY
# LIFESTAGE              PREMIUM_CUSTOMER
# OLDER FAMILIES         Budget            168363.25     45065
# YOUNG SINGLES/COUPLES  Mainstream        157621.60     38632
# RETIREES               Mainstream        155677.05     40518
# YOUNG FAMILIES         Budget            139345.85     37111
# OLDER SINGLES/COUPLES  Budget            136769.80     35220
#                        Mainstream        133393.80     34997
#                        Premium           132257.15     33984
# RETIREES               Budget            113147.80     28764
# OLDER FAMILIES         Mainstream        103445.55     27756
# RETIREES               Premium            97646.05     24884
# YOUNG FAMILIES         Mainstream         92788.75     25044
# MIDAGE SINGLES/COUPLES Mainstream         90803.85     22699
# YOUNG FAMILIES         Premium            84025.50     22406
# OLDER FAMILIES         Premium            80658.40     21771
# YOUNG SINGLES/COUPLES  Budget             61141.60     16671
# MIDAGE SINGLES/COUPLES Premium            58432.65     15526
# YOUNG SINGLES/COUPLES  Premium            41642.10     11331
# MIDAGE SINGLES/COUPLES Budget             35514.80      9496
# NEW FAMILIES           Budget             21928.45      5571
#                        Mainstream         17013.90      4319
#                        Premium            11491.10      2957

# %%
df_cd_seg = df_cd_merged[['LIFESTAGE','PREMIUM_CUSTOMER','TOT_SALES','PROD_QTY']].groupby(['LIFESTAGE', 'PREMIUM_CUSTOMER']).sum().sort_values(by='TOT_SALES', ascending=False)

# %%
df_cd_seg
# Out:
#                                          TOT_SALES  PROD_QTY
# LIFESTAGE              PREMIUM_CUSTOMER
# OLDER FAMILIES         Budget            168363.25     45065
# YOUNG SINGLES/COUPLES  Mainstream        157621.60     38632
# RETIREES               Mainstream        155677.05     40518
# YOUNG FAMILIES         Budget            139345.85     37111
# OLDER SINGLES/COUPLES  Budget            136769.80     35220
#                        Mainstream        133393.80     34997
#                        Premium           132257.15     33984
# RETIREES               Budget            113147.80     28764
# OLDER FAMILIES         Mainstream        103445.55     27756
# RETIREES               Premium            97646.05     24884
# YOUNG FAMILIES         Mainstream         92788.75     25044
# MIDAGE SINGLES/COUPLES Mainstream         90803.85     22699
# YOUNG FAMILIES         Premium            84025.50     22406
# OLDER FAMILIES         Premium            80658.40     21771
# YOUNG SINGLES/COUPLES  Budget             61141.60     16671
# MIDAGE SINGLES/COUPLES Premium            58432.65     15526
# YOUNG SINGLES/COUPLES  Premium            41642.10     11331
# MIDAGE SINGLES/COUPLES Budget             35514.80      9496
# NEW FAMILIES           Budget             21928.45      5571
#                        Mainstream         17013.90      4319
#                        Premium            11491.10      2957

# %%
df_cd_seg.merge(df_cd_seg_c, on=['LIFESTAGE', 'PREMIUM_CUSTOMER'], how='inner')
# Out:
#                  LIFESTAGE PREMIUM_CUSTOMER  TOT_SALES  PROD_QTY  \
# 0           OLDER FAMILIES           Budget  168363.25     45065
# 1    YOUNG SINGLES/COUPLES       Mainstream  157621.60     38632
# 2                 RETIREES       Mainstream  155677.05     40518
# 3           YOUNG FAMILIES           Budget  139345.85     37111
# 4    OLDER SINGLES/COUPLES           Budget  136769.80     35220
# 5    OLDER SINGLES/COUPLES       Mainstream  133393.80     34997
# 6    OLDER SINGLES/COUPLES          Premium  132257.15     33984
# 7                 RETIREES           Budget  113147.80     28764
# 8           OLDER FAMILIES       Mainstream  103445.55     27756
# 9                 RETIREES          Premium   97646.05     24884
# 10          YOUNG FAMILIES       Mainstream   92788.75     25044
# 11  MIDAGE SINGLES/COUPLES       Mainstream   90803.85     22699
# 12          YOUNG FAMILIES          Premium   84025.50     22406
# 13          OLDER FAMILIES          Premium   80658.40     21771
# 14   YOUNG SINGLES/COUPLES           Budget   61141.60     16671
# 15  MIDAGE SINGLES/COUPLES          Premium   58432.65     15526
# 16   YOUNG SINGLES/COUPLES          Premium   41642.10     11331
# 17  MIDAGE SINGLES/COUPLES           Budget   35514.80      9496
# 18            NEW FAMILIES           Budget   21928.45      5571
# 19            NEW FAMILIES       Mainstream   17013.90      4319
# 20            NEW FAMILIES          Premium   11491.10      2957
#
#     Cutomer_Counts
# 0             4675
# 1             8088
# 2             6479
# 3             4017
# 4             4929
# 5             4930
# 6             4750
# 7             4454
# 8             2831
# 9             3872
# 10            2728
# 11            3340
# 12            2433
# 13            2273
# 14            3779
# 15            2431
# 16            2574
# 17            1504
# 18            1112
# 19             849
# 20             588

# %%
df_cd_seg = df_cd_seg.merge(df_cd_seg_c, on=['LIFESTAGE', 'PREMIUM_CUSTOMER'], how='inner')

# %%
df_cd_seg['Sales_Per_Seg'] = df_cd_seg['PROD_QTY']/df_cd_seg['Cutomer_Counts']

# %%
df_cd_seg['Chips_Per_Seg'] = df_cd_seg['TOT_SALES']/df_cd_seg['Cutomer_Counts']

# %%
df_cd_seg['avg_price'] = df_cd_seg['TOT_SALES']/df_cd_seg['PROD_QTY']

# %%
df_cd_seg
# Out:
#                  LIFESTAGE PREMIUM_CUSTOMER  TOT_SALES  PROD_QTY  \
# 0           OLDER FAMILIES           Budget  168363.25     45065
# 1    YOUNG SINGLES/COUPLES       Mainstream  157621.60     38632
# 2                 RETIREES       Mainstream  155677.05     40518
# 3           YOUNG FAMILIES           Budget  139345.85     37111
# 4    OLDER SINGLES/COUPLES           Budget  136769.80     35220
# 5    OLDER SINGLES/COUPLES       Mainstream  133393.80     34997
# 6    OLDER SINGLES/COUPLES          Premium  132257.15     33984
# 7                 RETIREES           Budget  113147.80     28764
# 8           OLDER FAMILIES       Mainstream  103445.55     27756
# 9                 RETIREES          Premium   97646.05     24884
# 10          YOUNG FAMILIES       Mainstream   92788.75     25044
# 11  MIDAGE SINGLES/COUPLES       Mainstream   90803.85     22699
# 12          YOUNG FAMILIES          Premium   84025.50     22406
# 13          OLDER FAMILIES          Premium   80658.40     21771
# 14   YOUNG SINGLES/COUPLES           Budget   61141.60     16671
# 15  MIDAGE SINGLES/COUPLES          Premium   58432.65     15526
# 16   YOUNG SINGLES/COUPLES          Premium   41642.10     11331
# 17  MIDAGE SINGLES/COUPLES           Budget   35514.80      9496
# 18            NEW FAMILIES           Budget   21928.45      5571
# 19            NEW FAMILIES       Mainstream   17013.90      4319
# 20            NEW FAMILIES          Premium   11491.10      2957
#
#     Cutomer_Counts  Sales_Per_Seg  Chips_Per_Seg  avg_price
# 0             4675       9.639572      36.013529   3.736009
# 1             8088       4.776459      19.488328   4.080079
# 2             6479       6.253743      24.027944   3.842170
# 3             4017       9.238486      34.689034   3.754840
# 4             4929       7.145466      27.747981   3.883299
# 5             4930       7.098783      27.057566   3.811578
# 6             4750       7.154526      27.843611   3.891748
# 7             4454       6.458015      25.403637   3.933660
# 8             2831       9.804309      36.540286   3.726962
# 9             3872       6.426653      25.218505   3.924050
# 10            2728       9.180352      34.013471   3.705029
# 11            3340       6.796108      27.186781   4.000346
# 12            2433       9.209207      34.535758   3.750134
# 13            2273       9.578091      35.485438   3.704855
# 14            3779       4.411485      16.179307   3.667542
# 15            2431       6.386672      24.036466   3.763535
# 16            2574       4.402098      16.177972   3.675060
# 17            1504       6.313830      23.613564   3.739975
# 18            1112       5.009892      19.719829   3.936178
# 19             849       5.087161      20.039929   3.939315
# 20             588       5.028912      19.542687   3.886067

# %%
plt.figure(figsize=(14,8))
sns.barplot(data=df_cd_seg, x='LIFESTAGE', y='Chips_Per_Seg', hue='PREMIUM_CUSTOMER')
plt.xlabel(None)
plt.xticks(rotation=90)
# Out:
# (array([0, 1, 2, 3, 4, 5, 6]),
#  [Text(0, 0, 'OLDER FAMILIES'),
#   Text(1, 0, 'YOUNG SINGLES/COUPLES'),
#   Text(2, 0, 'RETIREES'),
#   Text(3, 0, 'YOUNG FAMILIES'),
#   Text(4, 0, 'OLDER SINGLES/COUPLES'),
#   Text(5, 0, 'MIDAGE SINGLES/COUPLES'),
#   Text(6, 0, 'NEW FAMILIES')])

# %%
plt.figure(figsize=(14,8))
sns.barplot(data=df_cd_seg, x='LIFESTAGE', y='Sales_Per_Seg', hue='PREMIUM_CUSTOMER')
plt.xlabel(None)
plt.xticks(rotation=90)
# Out:
# (array([0, 1, 2, 3, 4, 5, 6]),
#  [Text(0, 0, 'OLDER FAMILIES'),
#   Text(1, 0, 'YOUNG SINGLES/COUPLES'),
#   Text(2, 0, 'RETIREES'),
#   Text(3, 0, 'YOUNG FAMILIES'),
#   Text(4, 0, 'OLDER SINGLES/COUPLES'),
#   Text(5, 0, 'MIDAGE SINGLES/COUPLES'),
#   Text(6, 0, 'NEW FAMILIES')])

# %%
plt.figure(figsize=(14,8))
sns.barplot(data=df_cd_seg, x='LIFESTAGE', y='avg_price', hue='PREMIUM_CUSTOMER')
plt.xlabel(None)
plt.xticks(rotation=90)
# Out:
# (array([0, 1, 2, 3, 4, 5, 6]),
#  [Text(0, 0, 'OLDER FAMILIES'),
#   Text(1, 0, 'YOUNG SINGLES/COUPLES'),
#   Text(2, 0, 'RETIREES'),
#   Text(3, 0, 'YOUNG FAMILIES'),
#   Text(4, 0, 'OLDER SINGLES/COUPLES'),
#   Text(5, 0, 'MIDAGE SINGLES/COUPLES'),
#   Text(6, 0, 'NEW FAMILIES')])

# %%
plt.figure(figsize=(14,6))
sns.boxplot(x=df_cd_merged['LIFESTAGE'], y=df_cd_merged['TOT_SALES'])
plt.xticks(rotation=90)
plt.xlabel(None)
# Out:
# Text(0.5, 0, '')

# %%
plt.figure(figsize=(16,8))
sns.boxplot(x=df_cd_merged['TOT_SALES'], y=df_cd_merged['PREMIUM_CUSTOMER'], hue=df_cd_merged['LIFESTAGE'])
plt.yticks(rotation=90)
plt.ylabel(None)
# Out:
# Text(0, 0.5, '')

# %%
df_cd_seg
# Out:
#                  LIFESTAGE PREMIUM_CUSTOMER  TOT_SALES  PROD_QTY  \
# 0           OLDER FAMILIES           Budget  168363.25     45065
# 1    YOUNG SINGLES/COUPLES       Mainstream  157621.60     38632
# 2                 RETIREES       Mainstream  155677.05     40518
# 3           YOUNG FAMILIES           Budget  139345.85     37111
# 4    OLDER SINGLES/COUPLES           Budget  136769.80     35220
# 5    OLDER SINGLES/COUPLES       Mainstream  133393.80     34997
# 6    OLDER SINGLES/COUPLES          Premium  132257.15     33984
# 7                 RETIREES           Budget  113147.80     28764
# 8           OLDER FAMILIES       Mainstream  103445.55     27756
# 9                 RETIREES          Premium   97646.05     24884
# 10          YOUNG FAMILIES       Mainstream   92788.75     25044
# 11  MIDAGE SINGLES/COUPLES       Mainstream   90803.85     22699
# 12          YOUNG FAMILIES          Premium   84025.50     22406
# 13          OLDER FAMILIES          Premium   80658.40     21771
# 14   YOUNG SINGLES/COUPLES           Budget   61141.60     16671
# 15  MIDAGE SINGLES/COUPLES          Premium   58432.65     15526
# 16   YOUNG SINGLES/COUPLES          Premium   41642.10     11331
# 17  MIDAGE SINGLES/COUPLES           Budget   35514.80      9496
# 18            NEW FAMILIES           Budget   21928.45      5571
# 19            NEW FAMILIES       Mainstream   17013.90      4319
# 20            NEW FAMILIES          Premium   11491.10      2957
#
#     Cutomer_Counts  Sales_Per_Seg  Chips_Per_Seg  avg_price
# 0             4675       9.639572      36.013529   3.736009
# 1             8088       4.776459      19.488328   4.080079
# 2             6479       6.253743      24.027944   3.842170
# 3             4017       9.238486      34.689034   3.754840
# 4             4929       7.145466      27.747981   3.883299
# 5             4930       7.098783      27.057566   3.811578
# 6             4750       7.154526      27.843611   3.891748
# 7             4454       6.458015      25.403637   3.933660
# 8             2831       9.804309      36.540286   3.726962
# 9             3872       6.426653      25.218505   3.924050
# 10            2728       9.180352      34.013471   3.705029
# 11            3340       6.796108      27.186781   4.000346
# 12            2433       9.209207      34.535758   3.750134
# 13            2273       9.578091      35.485438   3.704855
# 14            3779       4.411485      16.179307   3.667542
# 15            2431       6.386672      24.036466   3.763535
# 16            2574       4.402098      16.177972   3.675060
# 17            1504       6.313830      23.613564   3.739975
# 18            1112       5.009892      19.719829   3.936178
# 19             849       5.087161      20.039929   3.939315
# 20             588       5.028912      19.542687   3.886067

# %%
from scipy.stats import ttest_ind

# %%
t_test_grp1 = df_cd_seg.query('LIFESTAGE == ["YOUNG SINGLES/COUPLES","MIDAGE SINGLES/COUPLES"] and PREMIUM_CUSTOMER == "Mainstream"')[['avg_price']]

# %%
t_test_grp2 = df_cd_seg.query('LIFESTAGE == ["YOUNG SINGLES/COUPLES","MIDAGE SINGLES/COUPLES"] and PREMIUM_CUSTOMER == ["Budget","Premium"]')[['avg_price']]

# %%
ttest_ind(t_test_grp1, t_test_grp2)
# Out:
# TtestResult(statistic=array([7.60688692]), pvalue=array([0.00160278]), df=array([4.]))

# %% [markdown]
# P_value = 0.0016
#
# Our Initial hypothesis of the difference between the 2 sample groups (1.YOUNG SINGLES/COUPLES","MIDAGE SINGLES/COUPLES : Mainstream, 2.YOUNG SINGLES/COUPLES","MIDAGE SINGLES/COUPLES:Budget & Premium) is significantly high is being REJECTED.

# %%
plt.figure(figsize=(16,8))
sns.boxplot(data=df_cd_merged.query('LIFESTAGE == "YOUNG SINGLES/COUPLES"'), x=('TOT_SALES'), y='PREMIUM_CUSTOMER')
plt.yticks(rotation=90)
plt.ylabel(None)
# Out:
# Text(0, 0.5, '')

# %%
plt.figure(figsize=(16,8))
sns.boxplot(data=df_cd_merged.query('LIFESTAGE == "MIDAGE SINGLES/COUPLES"'), x='TOT_SALES', y='PREMIUM_CUSTOMER')
plt.yticks(rotation=90)
plt.ylabel(None)
# Out:
# Text(0, 0.5, '')

# %%
df_merged
# Out:
#              DATE  STORE_NBR  LYLTY_CARD_NBR  TXN_ID  PROD_NBR  \
# 0      2018-10-17          1            1000       1         5
# 1      2018-09-16          1            1002       2        58
# 2      2019-03-07          1            1003       3        52
# 3      2019-03-08          1            1003       4       106
# 4      2018-11-02          1            1004       5        96
# ...           ...        ...             ...     ...       ...
# 264829 2018-10-01         88         2370751  240394        60
# 264830 2018-10-24         88         2370961  240480        70
# 264831 2018-10-27         88         2370961  240481        65
# 264832 2018-12-14         88         2373711  241815        16
# 264833 2018-12-25          0               0       0         0
#
#                                   PROD_NAME  PROD_QTY  TOT_SALES  PACK_SIZE  \
# 0              Natural Chip  Compny SeaSalt         2        6.0      175.0
# 1        Red Rock Deli Chikn & Garlic Aioli         1        2.7      150.0
# 2           Grain Waves Sour Cream & Chives         1        3.6      210.0
# 3            Natural ChipCo  Hony Soy Chckn         1        3.0      175.0
# 4                 WW Original Stacked Chips         1        1.9      160.0
# ...                                     ...       ...        ...        ...
# 264829    Kettle Tortilla ChpsFeta & Garlic         2        9.2      150.0
# 264830      Tyrrells Crisps  Lightly Salted         2        8.4      165.0
# 264831   Old El Paso Salsa Dip Chnky Tom Ht         2       10.2      300.0
# 264832  Smiths Crinkle Chips Salt & Vinegar         2       11.4      330.0
# 264833                                  NaN         0        NaN        NaN
#
#               BRAND              LIFESTAGE PREMIUM_CUSTOMER
# 0               NCC  YOUNG SINGLES/COUPLES          Premium
# 1               RRD  YOUNG SINGLES/COUPLES       Mainstream
# 2       Grain Waves         YOUNG FAMILIES           Budget
# 3               NCC         YOUNG FAMILIES           Budget
# 4        Woolworths  OLDER SINGLES/COUPLES       Mainstream
# ...             ...                    ...              ...
# 264829       Kettle         YOUNG FAMILIES          Premium
# 264830     Tyrrells         OLDER FAMILIES           Budget
# 264831          Old         OLDER FAMILIES           Budget
# 264832        Smith  YOUNG SINGLES/COUPLES       Mainstream
# 264833          NaN                    NaN              NaN
#
# [264834 rows x 12 columns]

# %%
df_merged.query('LIFESTAGE == "YOUNG SINGLES/COUPLES" and PREMIUM_CUSTOMER == "Mainstream"')['BRAND'].value_counts().reset_index()
# Out:
#           BRAND  count
# 0        Kettle   3844
# 1       Doritos   2541
# 2      Pringles   2315
# 3         Smith   1988
# 4     Infuzions   1250
# 5         Thins   1166
# 6           RRD    969
# 7      Twisties    900
# 8      Tostitos    890
# 9           Old    867
# 10         Cobs    864
# 11  Grain Waves    646
# 12     Tyrrells    619
# 13   Woolworths    599
# 14          NCC    394
# 15     Cheezels    346
# 16          CCs    222
# 17      Cheetos    166
# 18     Sunbites    128
# 19       French     78
# 20       Burger     62

# %%
df_merged.groupby('PACK_SIZE')['BRAND'].value_counts()
# Out:
# PACK_SIZE  BRAND
# 70.0       Infuzions       1507
# 90.0       Sunbites        3008
# 110.0      Infuzions      12694
#            Cobs            9693
# 125.0      Cheezels        1454
# 134.0      Pringles       25102
# 135.0      Kettle          3257
# 150.0      Kettle         19009
#            RRD            10372
#            Smith           7374
#            Doritos         6376
# 160.0      Woolworths      2970
# 165.0      RRD             7407
#            Tyrrells        6442
#            Cheetos         1448
# 170.0      Doritos        12613
#            Smith           7370
# 175.0      Kettle         19022
#            Thins          14075
#            Tostitos        9471
#            Smith           7506
#            NCC             7469
#            CCs             4551
#            Woolworths      2877
#            French          1418
# 180.0      Grain Waves     1468
# 190.0      Woolworths      1516
#            Cheetos         1479
# 200.0      Woolworths      4473
# 210.0      Grain Waves     6272
# 220.0      Burger          1564
# 250.0      Twisties        3169
# 270.0      Twisties        6285
# 300.0      Old             9324
#            Doritos         2921
#            Woolworths      2921
# 330.0      Smith           6339
#            Cheezels        3149
#            Doritos         3052
# 380.0      Smith           3233
#            Doritos         3183
# Name: count, dtype: int64

# %%
df_merged.query('LIFESTAGE == "YOUNG SINGLES/COUPLES" and PREMIUM_CUSTOMER == "Mainstream" and PACK_SIZE >= 300')['BRAND'].value_counts().reset_index()
# Out:
#         BRAND  count
# 0       Smith    928
# 1         Old    867
# 2     Doritos    768
# 3    Cheezels    287
# 4  Woolworths    120

# %%
df_merged.query('LIFESTAGE == "YOUNG SINGLES/COUPLES" and PREMIUM_CUSTOMER == "Budget" and PACK_SIZE >= 300')['BRAND'].value_counts().reset_index()
# Out:
#         BRAND  count
# 0     Doritos    315
# 1         Old    279
# 2       Smith    261
# 3  Woolworths    159
# 4    Cheezels     85

# %%
df_merged.query('LIFESTAGE == "YOUNG SINGLES/COUPLES" and PREMIUM_CUSTOMER == "Premium" and PACK_SIZE >= 300')['BRAND'].value_counts().reset_index()
# Out:
#         BRAND  count
# 0     Doritos    206
# 1       Smith    203
# 2         Old    178
# 3  Woolworths    105
# 4    Cheezels     65

# %%
df_merged.query('LIFESTAGE == "OLDER FAMILIES" and PREMIUM_CUSTOMER == "Mainstream" and PACK_SIZE >= 300')[['BRAND']].value_counts()
# Out:
# BRAND
# Doritos       512
# Smith         486
# Old           474
# Woolworths    173
# Cheezels      133
# Name: count, dtype: int64

# %%
df_merged.query('LIFESTAGE == "OLDER FAMILIES" and PREMIUM_CUSTOMER == "Budget" and PACK_SIZE >= 300')[['BRAND']].value_counts()
# Out:
# BRAND
# Doritos       826
# Smith         820
# Old           758
# Cheezels      275
# Woolworths    275
# Name: count, dtype: int64

# %%
df_merged.query('LIFESTAGE == "OLDER FAMILIES" and PREMIUM_CUSTOMER == "Premium" and PACK_SIZE >= 300')[['BRAND']].value_counts()
# Out:
# BRAND
# Smith         388
# Doritos       376
# Old           357
# Woolworths    145
# Cheezels      108
# Name: count, dtype: int64

# %%
df_merged.groupby(['PACK_SIZE','BRAND'])[['LIFESTAGE', 'PREMIUM_CUSTOMER']].value_counts()[-100:]
# Out:
# PACK_SIZE  BRAND     LIFESTAGE               PREMIUM_CUSTOMER
# 330.0      Cheezels  OLDER SINGLES/COUPLES   Budget              223
#                      RETIREES                Budget              201
#                      OLDER SINGLES/COUPLES   Mainstream          190
#                      MIDAGE SINGLES/COUPLES  Mainstream          186
#                      RETIREES                Premium             149
#                      YOUNG FAMILIES          Mainstream          145
#                                              Premium             142
#                      OLDER FAMILIES          Mainstream          133
#                                              Premium             108
#                      MIDAGE SINGLES/COUPLES  Premium             102
#                      YOUNG SINGLES/COUPLES   Budget               85
#                                              Premium              65
#                      MIDAGE SINGLES/COUPLES  Budget               47
#                      NEW FAMILIES            Mainstream           28
#                                              Budget               26
#                                              Premium              22
#            Doritos   YOUNG SINGLES/COUPLES   Mainstream          303
#                      OLDER FAMILIES          Budget              259
#                      RETIREES                Mainstream          240
#                      OLDER SINGLES/COUPLES   Budget              224
#                      YOUNG FAMILIES          Budget              217
#                      OLDER SINGLES/COUPLES   Mainstream          211
#                      RETIREES                Budget              204
#                      OLDER SINGLES/COUPLES   Premium             197
#                      OLDER FAMILIES          Mainstream          164
#                      RETIREES                Premium             162
#                      MIDAGE SINGLES/COUPLES  Mainstream          137
#                      YOUNG FAMILIES          Mainstream          130
#                                              Premium             115
#                      OLDER FAMILIES          Premium             111
#                      YOUNG SINGLES/COUPLES   Budget              100
#                      MIDAGE SINGLES/COUPLES  Premium              83
#                                              Budget               55
#                      YOUNG SINGLES/COUPLES   Premium              54
#                      NEW FAMILIES            Budget               42
#                                              Mainstream           29
#                                              Premium              15
#            Smith     YOUNG SINGLES/COUPLES   Mainstream          605
#                      OLDER FAMILIES          Budget              558
#                      RETIREES                Mainstream          509
#                      OLDER SINGLES/COUPLES   Premium             458
#                      YOUNG FAMILIES          Budget              448
#                      OLDER SINGLES/COUPLES   Budget              445
#                                              Mainstream          404
#                      RETIREES                Budget              389
#                      MIDAGE SINGLES/COUPLES  Mainstream          345
#                      RETIREES                Premium             324
#                      OLDER FAMILIES          Mainstream          322
#                      YOUNG FAMILIES          Mainstream          285
#                      OLDER FAMILIES          Premium             275
#                      YOUNG FAMILIES          Premium             246
#                      YOUNG SINGLES/COUPLES   Budget              176
#                      MIDAGE SINGLES/COUPLES  Premium             160
#                      YOUNG SINGLES/COUPLES   Premium             128
#                      MIDAGE SINGLES/COUPLES  Budget              105
#                      NEW FAMILIES            Budget               70
#                                              Mainstream           46
#                                              Premium              41
# 380.0      Doritos   YOUNG SINGLES/COUPLES   Mainstream          303
#                      RETIREES                Mainstream          251
#                      OLDER FAMILIES          Budget              248
#                      OLDER SINGLES/COUPLES   Premium             236
#                                              Mainstream          232
#                                              Budget              216
#                      YOUNG FAMILIES          Budget              216
#                      RETIREES                Premium             191
#                                              Budget              177
#                      OLDER FAMILIES          Mainstream          162
#                      MIDAGE SINGLES/COUPLES  Mainstream          138
#                      YOUNG FAMILIES          Premium             136
#                                              Mainstream          132
#                      OLDER FAMILIES          Premium             123
#                      MIDAGE SINGLES/COUPLES  Premium             102
#                      YOUNG SINGLES/COUPLES   Budget               98
#                                              Premium              71
#                      MIDAGE SINGLES/COUPLES  Budget               60
#                      NEW FAMILIES            Budget               41
#                                              Mainstream           35
#                                              Premium              15
#            Smith     YOUNG SINGLES/COUPLES   Mainstream          323
#                      OLDER FAMILIES          Budget              262
#                      RETIREES                Mainstream          246
#                      OLDER SINGLES/COUPLES   Budget              240
#                                              Mainstream          223
#                      YOUNG FAMILIES          Budget              215
#                      OLDER SINGLES/COUPLES   Premium             209
#                      RETIREES                Budget              198
#                                              Premium             178
#                      MIDAGE SINGLES/COUPLES  Mainstream          172
#                      OLDER FAMILIES          Mainstream          164
#                      YOUNG FAMILIES          Mainstream          151
#                                              Premium             129
#                      OLDER FAMILIES          Premium             113
#                      MIDAGE SINGLES/COUPLES  Premium             102
#                      YOUNG SINGLES/COUPLES   Budget               85
#                                              Premium              75
#                      MIDAGE SINGLES/COUPLES  Budget               54
#                      NEW FAMILIES            Budget               41
#                                              Mainstream           30
#                                              Premium              23
# Name: count, dtype: int64

# %%
df_merged.groupby('BRAND')['BRAND'].value_counts().sort_values(ascending=False)
# Out:
# BRAND
# Kettle         41288
# Smith          31822
# Doritos        28145
# Pringles       25102
# RRD            17779
# Woolworths     14757
# Infuzions      14201
# Thins          14075
# Cobs            9693
# Tostitos        9471
# Twisties        9454
# Old             9324
# Grain Waves     7740
# NCC             7469
# Tyrrells        6442
# Cheezels        4603
# CCs             4551
# Sunbites        3008
# Cheetos         2927
# Burger          1564
# French          1418
# Name: count, dtype: int64

# %%
df_merged.groupby('PACK_SIZE')['PACK_SIZE'].value_counts().sort_values(ascending=False)
# Out:
# PACK_SIZE
# 175.0    66389
# 150.0    43131
# 134.0    25102
# 110.0    22387
# 170.0    19983
# 165.0    15297
# 300.0    15166
# 330.0    12540
# 380.0     6416
# 270.0     6285
# 210.0     6272
# 200.0     4473
# 135.0     3257
# 250.0     3169
# 90.0      3008
# 190.0     2995
# 160.0     2970
# 220.0     1564
# 70.0      1507
# 180.0     1468
# 125.0     1454
# Name: count, dtype: int64

# %% [markdown]
# # Task 1 Finished with
#
# Young Families & Old Families with Highest Spending segment
#
# Mainstream: YOUNG SINGLES/COUPLES & MIDAGE SINGLES/COUPLES with High Avg_Price_Per_Chips
#
# Kettle,Smith & Doritos as the Most sold Brands
#
# 175g Most sold Pack Size
#
# Smith & Doritos Highest sold with larger packs chips
